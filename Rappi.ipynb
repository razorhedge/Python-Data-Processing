# %% [markdown]
# # Carga de Datos

# %%
import pandas as pd
import os
import numpy as np

# %%
#Carga del Archivo
mainpath="C:/Users/mromo/Developer/Python Course/python-ml-course-master/datasets"
filename= "Rappi/ConsolidadoOps_S27.xlsx"
fullpath = os.path.join(mainpath,filename)

# %%
#Creacion de BD Excel
xl = pd.ExcelFile(fullpath)

# %%
#Se toma la primera hoja como ejemplo
df1 = pd.read_excel(xl,"Resumen s26", header = 2)

# %%
#Verificacion de Carga Superior
df1.head()
# Out:
#         ID            Nombre                          Dirección  \
# 0      1.0    dely rodriguez                                  0
# 1  10041.0  Michell Corrales                  San Francisco 335
# 2  10042.0    Gustavo Mendez                Vicuña Mackena 1725
# 3  10045.0      Jose Abogado  Av Matta 747, dpto 1201, Santiago
# 4  10046.0   Juan Valenzuela           Pje. El Algarrobal 10045
#
#                         Correo         RUT  Horas de Conexión  Total Cupos_  \
# 0               dely@rappi.com           0           0.489700           0.0
# 1  michelljcorralesa@gmail.com  26209687-4           0.002500           0.0
# 2  gustavmendez_82@hotmail.com  25616019-6           0.167300           0.0
# 3  jose_daniel_132@hotmail.com  25608820-7          47.333333          31.0
# 4   j.s.valenzuela.s@gmail.com           0           0.138611           0.0
#
#    Cumplimiento Cupos (%)  Nro Ordenes Producción  Total Producción   \
# ...

# %%
#Verificacion de Carga Inferior
df1.tail()
# Out:
#           ID                   Nombre  \
# 103  10343.0  William Vaamonde Adames
# 104  10344.0   Raúl Jaimes Arciniegas
# 105  10346.0  Johan Rodriguez Morales
# 106  10353.0           Deivi Talavera
# 107      NaN                      NaN
#
#                                              Dirección  \
# 103                                                  0
# 104         Av.Presidente Balmaceda 2088 Quinta Normal
# 105  Av. Vicuña Mackena 2935 T A Depto 904 San Joaquin
# 106                                                  0
# 107                                                NaN
#
#                          Correo         RUT  Horas de Conexión  Total Cupos_  \
# 103  williamvaamondea@gmail.com           0           4.375278           0.0
# 104    jaimes.raul.ar@gmail.com  25978394-1          10.885833           0.0
# 105   soluciones_jr@hotmail.com  25694637-8           0.001944           0.0
# 106     deivi.alcala3@gmail.com           0           0.764167           0.0
# ...

# %%
#Verificacion de Cantidad de Datos
df1.shape
#Se certifica que estan todos los datos.
# Out:
# (108, 21)

# %% [markdown]
# # Analisis de Datos

# %%
#Origen de Columnas para Filtrar
df1.columns
# Out:
# Index(['ID', 'Nombre', 'Dirección', 'Correo', 'RUT', 'Horas de Conexión',
#        'Total Cupos_', 'Cumplimiento Cupos (%)', 'Nro Ordenes Producción',
#        'Total Producción ', 'Total Propinas_', 'Ganancia Sampling_',
#        'Promociones', 'Efectivo Recibido', 'Efectivo descontado',
#        'Dscto Equipamiento', 'Otras Asignaciones', 'Total a Pagar_',
#        'Pagos Realizados', 'Suma por Transferir', 'Deuda RT con Rappi'],
#       dtype='object')

# %%
#Resumen General de Estadisticos
df1.describe()
# Out:
#                  ID  Horas de Conexión  Total Cupos_  Cumplimiento Cupos (%)  \
# count    107.000000         107.000000    107.000000              107.000000
# mean   10079.420561          21.838529     22.845794                0.239669
# std      990.214957          26.089543     30.253053                0.315333
# min        1.000000           0.001944      0.000000                0.000000
# 25%    10078.000000           0.825972      0.000000                0.000000
# 50%    10113.000000          10.090000      2.000000                0.000000
# 75%    10314.500000          35.633611     47.000000                0.476293
# max    10353.000000          97.838611     90.000000                1.000000
#
#        Nro Ordenes Producción  Total Producción   Total Propinas_  \
# count              107.000000         107.000000       107.000000
# mean                 9.158879       13162.616822      3831.962617
# std                 12.767256       18593.854348      5358.503107
# ...

# %%
#Suma Columnas
df1.sum().astype(int)
# Out:
# ID                        1078498
# Horas de Conexión            2336
# Total Cupos_                 2444
# Cumplimiento Cupos (%)         25
# Nro Ordenes Producción        980
# Total Producción          1408400
# Total Propinas_            410020
# Ganancia Sampling_         281400
# Promociones               3467780
# Efectivo Recibido        -1628007
# Efectivo descontado      -1342592
# Dscto Equipamiento        -326398
# Otras Asignaciones          40000
# Total a Pagar_            3938610
# Pagos Realizados          2629044
# Suma por Transferir       2146260
# Deuda RT con Rappi        -836694
# dtype: int32

# %%
#Ejemplo 1: Maximos 10 en horas de conexion. (Se puede cambiar por cualquier otro parametro)
df1.sort_values("Horas de Conexión", ascending = False).head(10)
# Out:
#          ID              Nombre                            Dirección  \
# 30  10082.0       Jose De Pinho        San Bernardo Pje. Serbal 2355
# 35  10088.0      Yanier Veranes                                    0
# 31  10083.0         Rene Vielma          San Luis 1315 Independencia
# 36  10091.0      Julio Carrillo           Corrion 1319 Independencia
# 64  10127.0      Jorgen Agudelo          Victor Coccini 237 Recoleta
# 68  10256.0       Oscar Monagas   Presidente Balmaceda 2914 S.Centro
# 21  10070.0         Saul Valero            Marin 382 Santiago Centro
# 53  10113.0      Hector Dugarte             Av. Matta 1438, Santiago
# 24  10075.0        Saul Serrano  Calle Santiago 1320 Comuna Santiago
# 66  10150.0  Wilkinmar Martinez              Av. Nueva Imperial 1252
#
#                                     Correo         RUT  Horas de Conexión  \
# 30                  josedepinho9@gmail.com  25695263-7          97.838611
# ...

# %%
#Ejemplo 2: Todos los pagos pendientes. 
df1[df1['Deuda RT con Rappi'] < 0]
# Out:
#          ID                      Nombre  \
# 3   10045.0                Jose Abogado
# 6   10048.0               Edwin Aguirre
# 8   10050.0             Nicolas Pechieu
# 9   10056.0              Carlos Morales
# 11  10059.0                 Jose Vielma
# 12  10060.0             Gerardo Sanchez
# 15  10064.0                  Yein Armas
# 17  10066.0                Jhonny Rojas
# 20  10069.0                  Dixon Pino
# 26  10077.0               Edwin Huamani
# 28  10080.0               Jonas Sanchez
# 29  10081.0                Cesar Correa
# 32  10085.0                Daniel Mejia
# 34  10087.0                 Felipe Ruiz
# 37  10092.0               Rhonny Suarez
# 47  10105.0              Matias Badillo
# 48  10106.0                Jawer Arenas
# 56  10117.0                Frank Angulo
# 57  10118.0          Williams Hernandez
# 62  10125.0               Nicolas Atala
# 64  10127.0              Jorgen Agudelo
# 67  10167.0  Cindy Paola Aparicio Goyes
#
# ...

# %%
#Ejemplo 3: Correlacion entre horas de conexion y cumplimiento (Se puede hacer con cualquier dimension)
df1['Horas de Conexión'].corr(df1['Cumplimiento Cupos (%)'])
#Es decir, en un 78% de los casos mientras mas horas se conectan, mejores resultados obtienen. Habria que revisar los outliers.
# Out:
# 0.7879459637405755

# %%
df1.columns
# Out:
# Index(['ID', 'Nombre', 'Dirección', 'Correo', 'RUT', 'Horas de Conexión',
#        'Total Cupos_', 'Cumplimiento Cupos (%)', 'Nro Ordenes Producción',
#        'Total Producción ', 'Total Propinas_', 'Ganancia Sampling_',
#        'Promociones', 'Efectivo Recibido', 'Efectivo descontado',
#        'Dscto Equipamiento', 'Otras Asignaciones', 'Total a Pagar_',
#        'Pagos Realizados', 'Suma por Transferir', 'Deuda RT con Rappi'],
#       dtype='object')
