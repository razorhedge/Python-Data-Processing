# %%
import pandas as pd
import numpy as np
import os

# %%
mainpath = "C:/Users/mromo/Desktop/Rappi/Datasets"
url = "https://api.airtable.com/v0/appbufpjaIvBjAG7d/Datos%20Bancarios"
t= pd.DataFrame()
for i in range(0,99):
    t[i] = []

# %%
import requests

headers = {'Authorization': 'Bearer keyJfuJD086zSDav8','Content-type':'application/json'}
indice = 0
for offset in range(0, 1000,100):
    r = requests.get(url, headers=headers)
    x = pd.DataFrame(r.json())
    url = url + '&offset' + str(x['offset'])
    x = x['records'].apply(pd.Series)
    x = x['fields'].apply(pd.Series)
    t[indice] = t[indice].append(x)
    indice+=1
    print(indice)
# Out:
# C:\Users\mromo\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3169             try:
# -> 3170                 value = Series(value)
#    3171             except:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     273                 data = _sanitize_array(data, index, dtype, copy,
# --> 274                                        raise_cast_failure=True)
#     275
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    4162         else:
# -> 4163             subarr = com._asarray_tuplesafe(data, dtype=dtype)
#    4164
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in _asarray_tuplesafe(values, dtype)
#     316         # TODO: verify whether any path hits this except #18819 (invalid)
# --> 317         values = [tuple(x) for x in values]
#     318         result = construct_1d_object_array_from_listlike(values)
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in <listcomp>(.0)
#     316         # TODO: verify whether any path hits this except #18819 (invalid)
# --> 317         values = [tuple(x) for x in values]
#     318         result = construct_1d_object_array_from_listlike(values)
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-de4d12c4dc92> in <module>()
#       9     x = x['records'].apply(pd.Series)
#      10     x = x['fields'].apply(pd.Series)
# ---> 11     t[indice] = t[indice].append(x)
#      12     indice+=1
#      13     print(indice)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3188         """
#    3189
# -> 3190         self._ensure_valid_index(value)
#    3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3170                 value = Series(value)
#    3171             except:
# -> 3172                 raise ValueError('Cannot set a frame with no defined index '
#    3173                                  'and a value that cannot be converted to a '
#    3174                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
x
# Out:
#     ID_RegCuenta  RUT Titular                    Nombre Completo Titular  \
# 0            157   24313316-5                John Anthony Gonzales Silva
# 1            385   18641996-0                         Benjamin Arancibia
# 2             82   20018946-9           Daniela Alejandra Gonzalez Mella
# 3            552   26224828-3            Alberto Argenis Espinoza Moreno
# 4            497   25626316-5               Jose Daniel Marquez Barahona
# 5            562   17256255-8          Bastian Alejandro Fajardo Poblete
# 6            934   26168183-8             Fernando Andres Gonzalez Ramos
# 7            856   25310796-0                Jenny Maritza Molina Villao
# 8            501   26316638-8                  Liborio Jose Vielma Vivas
# 9            505   18990542-4                   David Abdon Roman Cortes
# 10           849   26159740-3                     Juan Carlos Acuña Mago
# 11          1189   26115541-9            manuel antonio freites albarran
# 12            28   18243301-2          Ricardo Andres Valenzuela Vergara
# 13          1116   17782942-0            Ignacio Nicolas Jose Soto Arias
# 14          1308   18863795-7  Antonio Francisco Renato Machado Chamorro
# 15           486   18117524-9              Pablo Ignacio Orellana Quiroz
# 16          1195   26211263-2                 Roger alejandro muñoz leon
# 17          1342   25726882-9             Francis Johanna Zamora Guerra
# 18          1133   25869600-K         Ricardo Alberto Colmenarez Brandes
# 19          1201   25556564-8              Daywil Antonio Velasco duran
# 24          23966948    12. Banco del Estado de Chile
# 25          26369998    12. Banco del Estado de Chile
# 26          25271336    12. Banco del Estado de Chile
# 27          26109711    12. Banco del Estado de Chile
# 28          25668211    12. Banco del Estado de Chile
# 29          25932115    12. Banco del Estado de Chile
# ..               ...                              ...
# 70         263390482    12. Banco del Estado de Chile
# 71          26184563    12. Banco del Estado de Chile
# 72          26198748    12. Banco del Estado de Chile
# 73          26123611    12. Banco del Estado de Chile
# 74          26060303    12. Banco del Estado de Chile
# 75         137563053    12. Banco del Estado de Chile
# 76          26278323    12. Banco del Estado de Chile
# 77                 0    12. Banco del Estado de Chile
# 78          25582684    12. Banco del Estado de Chile
# 79          25986667    12. Banco del Estado de Chile
# 80       26160158114    12. Banco del Estado de Chile
# 81          25878364    12. Banco del Estado de Chile
# 82          16510329    12. Banco del Estado de Chile
# 83         166279623  16. Banco Crédito e Inversiones
# 84       50012230951              51. Banco Falabella
# 85          25352604    12. Banco del Estado de Chile
# 86          26352873    12. Banco del Estado de Chile
# 87          25668729    12. Banco del Estado de Chile
# 88          25545428    12. Banco del Estado de Chile
# 89          18192398    12. Banco del Estado de Chile
# 90          25655345    12. Banco del Estado de Chile
# 91          18609020    12. Banco del Estado de Chile
# 92          15639719    12. Banco del Estado de Chile
# 93          25600737    12. Banco del Estado de Chile
# 94          25807342    12. Banco del Estado de Chile
# 95          26135654    12. Banco del Estado de Chile
# 96          71561364   37. Banco Santander - Santiago
# 97          20466678    12. Banco del Estado de Chile
# 98          26368443    12. Banco del Estado de Chile
# 99          26162297    12. Banco del Estado de Chile
#
#                Tipo de Cuenta                 SKID Predeterminada  \
# 0                Cuenta Vista  [recdW9dewDcrvxzW2]             Si
# 1    CuentaRUT (Cuenta Vista)  [reclQlg4xhSbU8uHn]             Si
# 2    CuentaRUT (Cuenta Vista)  [recaqhskM7SJP33gx]             Si
# 3    CuentaRUT (Cuenta Vista)  [rec6KM3BREWFywBDB]             Si
# 4                Cuenta Vista  [recReawdc4CHPg21z]             Si
# 5    CuentaRUT (Cuenta Vista)  [recb72QuutcR0M9E6]             Si
# 6    CuentaRUT (Cuenta Vista)  [reczGbiCNLg4Tn0Rb]             Si
# 7    CuentaRUT (Cuenta Vista)  [rec0AvhvLL0D4q2Cr]             Si
# 8    CuentaRUT (Cuenta Vista)  [rec5Oq0e3da4MTabr]             Si
# 9    CuentaRUT (Cuenta Vista)  [rec3VmZYl6WIBibcb]             Si
# 10   CuentaRUT (Cuenta Vista)  [recA9mLXdHnPSx6QP]             Si
# 11   CuentaRUT (Cuenta Vista)  [reco4SzHb1lTOP9wd]             Si
# 12   CuentaRUT (Cuenta Vista)  [recjYU9rfUIJdXd70]             Si
# 13               Cuenta Vista  [receOiT8P8kJh6sM7]             Si
# 14   CuentaRUT (Cuenta Vista)  [recPqXGbP8ohNpA2a]            NaN
# 15   CuentaRUT (Cuenta Vista)  [recwS0VmCtLECQHhm]             Si
# 16   CuentaRUT (Cuenta Vista)                  NaN             Si
# 17   CuentaRUT (Cuenta Vista)                  NaN            NaN
# 18   CuentaRUT (Cuenta Vista)  [recmDJuoD8Zb48jtQ]             Si
# 19   CuentaRUT (Cuenta Vista)  [recNvMoZ7LWWXfexT]             Si
# 20   CuentaRUT (Cuenta Vista)  [recitBP4oj5UywoSr]             Si
# 21  MACH - BCI (Cuenta Vista)  [reciYSCCgWzvLsYvq]             Si
# 22   CuentaRUT (Cuenta Vista)  [recAPsmWemxK94Egt]             Si
# 23   CuentaRUT (Cuenta Vista)  [recMcHbu430pjoJqr]             Si
# 24   CuentaRUT (Cuenta Vista)  [recpkqnFaREQA7QEH]             Si
# 25   CuentaRUT (Cuenta Vista)  [rece43GNHYjsIdxtU]            NaN
# 26   CuentaRUT (Cuenta Vista)                  NaN            NaN
# 27   CuentaRUT (Cuenta Vista)                  NaN            NaN
# 28   CuentaRUT (Cuenta Vista)  [rec9xmI77n3CxdKyX]             Si
# 29   CuentaRUT (Cuenta Vista)  [recJA9laV4wTZzin0]             Si
# ..                        ...                  ...            ...
# 70   CuentaRUT (Cuenta Vista)  [recdVIzZWGiQPnG55]             Si
# 71   CuentaRUT (Cuenta Vista)  [recojl2k8Zuab38Qm]             Si
# 72   CuentaRUT (Cuenta Vista)  [rec7gm014eVbdxd40]             Si
# 73   CuentaRUT (Cuenta Vista)  [recPRPsPMlTDmY3KP]             Si
# 74   CuentaRUT (Cuenta Vista)  [recvIrQIs169DtrSL]             Si
# 75   CuentaRUT (Cuenta Vista)  [recfbys11TSlWxahC]             Si
# 76   CuentaRUT (Cuenta Vista)  [recPMQwcKjSVKMWF7]             Si
# 77   CuentaRUT (Cuenta Vista)  [rechsewzIcRmwJOtb]             Si
# 78   CuentaRUT (Cuenta Vista)  [recmp7kv7W1Q5rTcU]             Si
# 79   CuentaRUT (Cuenta Vista)  [recakooGjlb0nbyun]            NaN
# 80           Cuenta de Ahorro                  NaN             Si
# 81   CuentaRUT (Cuenta Vista)  [recNZju6ENwt5E3kS]             Si
# 82   CuentaRUT (Cuenta Vista)  [recIjBHoKPPXZ1xQJ]             Si
# 83   CuentaRUT (Cuenta Vista)                  NaN             Si
# 84               Cuenta Vista  [recJivpOIecWw5brC]             Si
# 85   CuentaRUT (Cuenta Vista)  [receOsJFrUOT5beYI]             Si
# 86   CuentaRUT (Cuenta Vista)  [recABgL4rv6ou0HV1]            NaN
# 87   CuentaRUT (Cuenta Vista)  [rec08HYftwGmCv7WH]             Si
# 88   CuentaRUT (Cuenta Vista)  [recUQG0HaTW0o91Sp]             Si
# 89   CuentaRUT (Cuenta Vista)  [reclTNhJNyKyO74az]             Si
# 90   CuentaRUT (Cuenta Vista)  [rec271NcndyGpUqLT]             Si
# 91   CuentaRUT (Cuenta Vista)  [recb4AD7UJW6HG59Q]             Si
# 92   CuentaRUT (Cuenta Vista)  [reccI1wDgeqCGml00]             Si
# 93   CuentaRUT (Cuenta Vista)  [recyQVOuOivWoYYDN]             Si
# 94   CuentaRUT (Cuenta Vista)  [recSUsW0YPA9ZhVyz]             Si
# 95   CuentaRUT (Cuenta Vista)  [recKZCXHd1rInJt2E]             Si
# 96           Cuenta Corriente  [rec2kscWoKyBl5zJ9]             Si
# 97   CuentaRUT (Cuenta Vista)  [recvumwRuBzKgmGtl]             Si
# 98   CuentaRUT (Cuenta Vista)  [rec1fnzH8XFoQVmgd]             Si
# 99   CuentaRUT (Cuenta Vista)  [rec7he8kwJI4gcwv7]             Si
#
#                    Timestamp     ID
# 0   2018-07-28T04:59:56.000Z  10612
# 1   2018-07-30T22:31:56.000Z  10128
# 2   2018-07-23T20:16:17.000Z  10682
# 3   2018-07-31T02:36:34.000Z  10911
# 4   2018-07-31T00:32:16.000Z  10926
# 5   2018-07-31T03:39:17.000Z  10602
# 6   2018-08-08T19:09:33.000Z  11078
# 7   2018-08-06T15:57:42.000Z  10617
# 8   2018-07-31T00:32:44.000Z  10527
# 9   2018-07-31T00:35:01.000Z  10544
# 10  2018-08-06T15:43:55.000Z  11053
# 11  2018-09-04T14:28:21.000Z  11460
# 12  2018-07-20T03:55:02.000Z  10467
# 13  2018-08-27T23:40:04.000Z  11412
# 14  2018-09-14T03:36:13.000Z  10782
# 15  2018-07-31T00:27:59.000Z  10499
# 16  2018-09-04T22:29:17.000Z    NaN
# 17  2018-09-16T15:39:47.000Z    NaN
# 18  2018-08-30T21:06:13.000Z  11485
# 19  2018-09-05T13:11:59.000Z  11566
# 20  2018-08-06T19:00:38.000Z  11001
# 21  2018-08-04T05:37:03.000Z  10962
# 22  2018-07-31T00:17:17.000Z  10704
# 23  2018-07-30T23:59:07.000Z  10443
# 24  2018-07-31T01:24:17.000Z  10940
# 25  2018-09-16T21:29:23.000Z  11332
# 26  2018-09-10T22:42:23.000Z    NaN
# 27  2018-09-11T19:56:57.000Z    NaN
# 28  2018-09-09T23:56:26.000Z  11577
# 29  2018-07-20T02:15:16.000Z  10633
# ..                       ...    ...
# 70  2018-07-31T05:36:19.000Z  10938
# 71  2018-07-23T17:57:30.000Z  10679
# 72  2018-07-20T01:17:56.000Z  10623
# 73  2018-08-21T21:16:32.000Z  11236
# 74  2018-08-06T15:26:51.000Z  10565
# 75  2018-07-31T13:34:25.000Z  10541
# 76  2018-08-31T19:52:26.000Z  11429
# 77  2018-08-08T21:19:07.000Z  10885
# 78  2018-07-31T13:57:54.000Z  10501
# 79  2018-09-20T16:20:54.000Z  11457
# 80  2018-09-09T22:31:12.000Z    NaN
# 81  2018-07-24T20:59:04.000Z  10414
# 82  2018-07-20T01:12:17.000Z  10466
# 83  2018-09-03T23:49:28.000Z    NaN
# 84  2018-07-28T10:12:46.000Z  10696
# 85  2018-08-14T18:17:19.000Z  11237
# 86  2018-09-21T15:27:11.000Z  11922
# 87  2018-08-20T02:08:06.000Z  10976
# 88  2018-08-08T20:44:50.000Z  11027
# 89  2018-08-06T17:02:58.000Z  10864
# 90  2018-07-31T01:14:40.000Z  10554
# 91  2018-07-31T00:43:26.000Z  10762
# 92  2018-07-30T21:42:08.000Z  10087
# 93  2018-07-31T00:42:45.000Z  10733
# 94  2018-07-31T13:53:01.000Z  10494
# 95  2018-07-31T00:32:17.000Z  10505
# 96  2018-07-28T06:18:35.000Z  10731
# 97  2018-08-04T08:50:25.000Z  10887
# 98  2018-08-02T20:46:57.000Z  10336
# 99  2018-07-30T23:17:54.000Z  10314
#
# [100 rows x 10 columns]

# %%
r.headers

# %%
response = r.content

# %%
import json

import csv

data_parsed = json.loads(r.content)

emp_data = data_parsed['records']

employ_data = open(mainpath + '/' + 'Bancario Directo.csv', 'w')

csvwriter = csv.writer(employ_data, delimiter = ',', quotechar= ' ', quoting = csv.QUOTE_MINIMAL)

count = 0

for emp in emp_data:

      if count == 0:
              
             header = emp['fields'].keys()
             csvwriter.writerow(header)
             print(header)
             count += 1
                
      csvwriter.writerow(emp['fields'].values())

employ_data.close()
